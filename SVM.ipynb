# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("D:\\Learning\\Python\\ineuron classes\\Full-Stack-Data-Scientist\\svm\\winequality-red.csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1507            7.5              0.38         0.57             2.3      0.106
# 1380            7.5              0.57         0.02             2.6      0.077
# 610             8.8              0.24         0.54             2.5      0.083
# 9               7.5              0.50         0.36             6.1      0.071
# 1401            7.9              0.69         0.21             2.1      0.080
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1507                  5.0                  12.0  0.99605  3.36       0.55
# 1380                 11.0                  35.0  0.99557  3.36       0.62
# 610                  25.0                  57.0  0.99830  3.39       0.54
# 9                    17.0                 102.0  0.99780  3.35       0.80
# 1401                 33.0                 141.0  0.99620  3.25       0.51
#
#       alcohol  quality
# 1507     11.4        6
# ...

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 240

# %%
data[data.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
x = data.drop("quality",axis=1)

# %%
y=data["quality"]

# %% [markdown]
# # preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y= train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
scaled_train = scaler.fit_transform(train_x)

# %% [markdown]
# # SVM Model building

# %%
import seaborn as sns

# %%
sns.pairplot(data,hue="quality")

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(scaled_train,train_y)
# Out:
# SVC()

# %%
scaled_test_x = scaler.transform(test_x)

# %%
y_pred = model.predict(scaled_test_x)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,y_pred)*100
# Out:
# 59.84848484848485

# %%
round(accuracy_score(test_y,y_pred)*100,2)
# Out:
# 59.85

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {"c":[0.1,1,10,100],"gama":[1,0.5,0.1,0.01,0.001]}

# %%
grid = GridSearchCV(scaled_train,train_y)
